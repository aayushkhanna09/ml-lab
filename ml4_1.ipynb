# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushkhanna09/ml-lab/blob/main/ml4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

data = pd.read_csv("TvMarketing.csv")
print(data.head())
print(data.info())
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB
# None

# %%
plt.scatter(data['TV'], data['Sales'])
plt.xlabel("TV Budget")
plt.ylabel("Sales")
plt.title("TV Budget vs Sales")
plt.show()

# %%
X = data[['TV']]
y = data['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)
# Out:
# Training shape: (160, 1)
# Testing shape: (40, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

b0 = model.intercept_
b1 = model.coef_[0]

print("Intercept:", b0)
print("Slope:", b1)
# Out:
# Intercept: 6.879469921057685
# Slope: 0.04910666951857926

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.title("Best Fit Line")
plt.show()

# %%
y_pred = model.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
# Out:
#      Actual  Predicted
# 93     22.2  19.200333
# 147    25.4  18.822212
# 146    13.2  18.669981
# 1      10.4   9.064717
# 34      9.5  11.578978
# 159    12.9  13.346818
# 150    16.1  20.663712
# 77     14.2  12.796824
# 94     11.5  12.153526
# 69     22.3  17.525796
# 43     12.9  17.039640
# 21     12.5  18.537393
# 171    14.5  14.957517
# 32      9.6  11.652638
# 75      8.7   7.709373
# 46     10.6  11.284338
# 87     16.0  12.315578
# 139    20.7  15.959293
# 8       4.8   7.301787
# 100    11.7  17.800793
# 54     20.2  19.779792
# 129     9.7   9.806227
# 38     10.1   8.995967
# 196     9.7  11.505318
# 149    10.1   9.074538
# 24      9.7   9.938815
# 88     12.9  11.215589
# 138     9.6   8.991057
# 3      18.5  14.319130
# 178    11.8  20.467285
# 173    11.7  15.149033
# 161    13.3  11.087911
# 168    17.1  17.457047
# 154    15.6  16.101702
# 45     14.9  15.478048
# 165    11.9  18.394984
# 7      13.2  12.782092
# 182     8.7   9.639265
# 71     12.4  12.271382
# 61     24.2  19.711043

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# RMSE: 3.376350571671578
# R2 Score: 0.4547240646536287
